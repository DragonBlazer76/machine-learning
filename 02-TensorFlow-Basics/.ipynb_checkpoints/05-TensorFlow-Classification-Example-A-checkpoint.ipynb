# %% [markdown]
# # TensorFlow Classification Example A

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp505sun4z
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp505sun4z', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a168c99b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp505sun4z/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 272.953
# INFO:tensorflow:loss = 6.191663, step = 101 (0.369 sec)
# INFO:tensorflow:global_step/sec: 504.395
# INFO:tensorflow:loss = 6.77427, step = 201 (0.198 sec)
# INFO:tensorflow:global_step/sec: 473.026
# INFO:tensorflow:loss = 4.6752357, step = 301 (0.209 sec)
# INFO:tensorflow:global_step/sec: 502.159
# INFO:tensorflow:loss = 5.3631153, step = 401 (0.199 sec)
# INFO:tensorflow:global_step/sec: 488.3
# INFO:tensorflow:loss = 3.0733562, step = 501 (0.205 sec)
# INFO:tensorflow:global_step/sec: 517.465
# INFO:tensorflow:loss = 5.7870297, step = 601 (0.193 sec)
# INFO:tensorflow:global_step/sec: 536.178
# INFO:tensorflow:loss = 5.856599, step = 701 (0.188 sec)
# INFO:tensorflow:global_step/sec: 531.463
# INFO:tensorflow:loss = 4.871339, step = 801 (0.188 sec)
# INFO:tensorflow:global_step/sec: 475.574
# INFO:tensorflow:loss = 4.5920587, step = 901 (0.209 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp505sun4z/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.4371753.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-24-01:16:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp505sun4z/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-24-01:16:41
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.7849474, auc_precision_recall = 0.6203296, average_loss = 0.53256, global_step = 1000, label/mean = 0.34251967, loss = 5.202701, precision = 0.6075949, prediction/mean = 0.3676601, recall = 0.55172414
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp505sun4z/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7849474,
#  'auc_precision_recall': 0.6203296,
#  'average_loss': 0.53256,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.202701,
#  'precision': 0.6075949,
#  'prediction/mean': 0.3676601,
#  'recall': 0.55172414}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp505sun4z/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5399906], dtype=float32),
#   'logits': array([0.16030478], dtype=float32),
#   'probabilities': array([0.46000943, 0.5399906 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6290944], dtype=float32),
#   'logits': array([0.5283339], dtype=float32),
#   'probabilities': array([0.37090555, 0.6290944 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38123676], dtype=float32),
#   'logits': array([-0.4843021], dtype=float32),
#   'probabilities': array([0.61876327, 0.38123676], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32367754], dtype=float32),
#   'logits': array([-0.73692226], dtype=float32),
#   'probabilities': array([0.67632246, 0.32367754], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13873947], dtype=float32),
#   'logits': array([-1.8257992], dtype=float32),
#   'probabilities': array([0.86126053, 0.13873947], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6926939], dtype=float32),
#   'logits': array([0.8127438], dtype=float32),
#   'probabilities': array([0.30730614, 0.6926939 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59749126], dtype=float32),
#   'logits': array([0.395023], dtype=float32),
#   'probabilities': array([0.4025087 , 0.59749126], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35305142], dtype=float32),
#   'logits': array([-0.6056531], dtype=float32),
#   'probabilities': array([0.6469486 , 0.35305142], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24101937], dtype=float32),
#   'logits': array([-1.147099], dtype=float32),
#   'probabilities': array([0.7589807 , 0.24101937], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23846914], dtype=float32),
#   'logits': array([-1.1610909], dtype=float32),
#   'probabilities': array([0.7615308, 0.2384691], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12274406], dtype=float32),
#   'logits': array([-1.9666975], dtype=float32),
#   'probabilities': array([0.8772559 , 0.12274405], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14608306], dtype=float32),
#   'logits': array([-1.7656586], dtype=float32),
#   'probabilities': array([0.853917  , 0.14608306], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29419222], dtype=float32),
#   'logits': array([-0.87510955], dtype=float32),
#   'probabilities': array([0.7058078 , 0.29419222], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5776609], dtype=float32),
#   'logits': array([0.31317866], dtype=float32),
#   'probabilities': array([0.42233902, 0.5776609 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16760562], dtype=float32),
#   'logits': array([-1.6026926], dtype=float32),
#   'probabilities': array([0.83239436, 0.16760562], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33018735], dtype=float32),
#   'logits': array([-0.70733774], dtype=float32),
#   'probabilities': array([0.6698126 , 0.33018735], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3664526], dtype=float32),
#   'logits': array([-0.5474656], dtype=float32),
#   'probabilities': array([0.6335474, 0.3664526], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12183401], dtype=float32),
#   'logits': array([-1.9751761], dtype=float32),
#   'probabilities': array([0.878166  , 0.12183401], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36464325], dtype=float32),
#   'logits': array([-0.55526716], dtype=float32),
#   'probabilities': array([0.6353567 , 0.36464325], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13522212], dtype=float32),
#   'logits': array([-1.8555539], dtype=float32),
#   'probabilities': array([0.86477786, 0.13522214], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21412738], dtype=float32),
#   'logits': array([-1.3002236], dtype=float32),
#   'probabilities': array([0.78587264, 0.21412739], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29799318], dtype=float32),
#   'logits': array([-0.85687256], dtype=float32),
#   'probabilities': array([0.7020068 , 0.29799315], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67513597], dtype=float32),
#   'logits': array([0.7315074], dtype=float32),
#   'probabilities': array([0.32486403, 0.67513597], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20775011], dtype=float32),
#   'logits': array([-1.3385409], dtype=float32),
#   'probabilities': array([0.79224986, 0.20775011], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17465843], dtype=float32),
#   'logits': array([-1.552965], dtype=float32),
#   'probabilities': array([0.8253415 , 0.17465843], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77142], dtype=float32),
#   'logits': array([1.2163466], dtype=float32),
#   'probabilities': array([0.22858001, 0.77142   ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17840703], dtype=float32),
#   'logits': array([-1.5271775], dtype=float32),
#   'probabilities': array([0.821593  , 0.17840703], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30460444], dtype=float32),
#   'logits': array([-0.8254668], dtype=float32),
#   'probabilities': array([0.6953955 , 0.30460444], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09729671], dtype=float32),
#   'logits': array([-2.2276287], dtype=float32),
#   'probabilities': array([0.90270334, 0.09729671], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5920836], dtype=float32),
#   'logits': array([0.37258554], dtype=float32),
#   'probabilities': array([0.4079164, 0.5920836], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9421819], dtype=float32),
#   'logits': array([2.7908964], dtype=float32),
#   'probabilities': array([0.0578181, 0.9421819], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40996397], dtype=float32),
#   'logits': array([-0.36411434], dtype=float32),
#   'probabilities': array([0.59003603, 0.40996397], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31286567], dtype=float32),
#   'logits': array([-0.7867559], dtype=float32),
#   'probabilities': array([0.6871343 , 0.31286564], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56743985], dtype=float32),
#   'logits': array([0.27141333], dtype=float32),
#   'probabilities': array([0.43256015, 0.56743985], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23926282], dtype=float32),
#   'logits': array([-1.1567253], dtype=float32),
#   'probabilities': array([0.7607372 , 0.23926285], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3788115], dtype=float32),
#   'logits': array([-0.49459594], dtype=float32),
#   'probabilities': array([0.6211885 , 0.37881148], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5245011], dtype=float32),
#   'logits': array([0.0980829], dtype=float32),
#   'probabilities': array([0.4754989, 0.5245011], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6428558], dtype=float32),
#   'logits': array([0.5877812], dtype=float32),
#   'probabilities': array([0.3571441, 0.6428558], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7566842], dtype=float32),
#   'logits': array([1.134586], dtype=float32),
#   'probabilities': array([0.24331576, 0.7566842 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32987136], dtype=float32),
#   'logits': array([-0.70876694], dtype=float32),
#   'probabilities': array([0.67012864, 0.32987136], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17812437], dtype=float32),
#   'logits': array([-1.5291071], dtype=float32),
#   'probabilities': array([0.8218756 , 0.17812435], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53051865], dtype=float32),
#   'logits': array([0.1222266], dtype=float32),
#   'probabilities': array([0.46948132, 0.53051865], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1454895], dtype=float32),
#   'logits': array([-1.7704248], dtype=float32),
#   'probabilities': array([0.8545105, 0.1454895], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5401304], dtype=float32),
#   'logits': array([0.16086757], dtype=float32),
#   'probabilities': array([0.4598696, 0.5401304], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13441925], dtype=float32),
#   'logits': array([-1.862437], dtype=float32),
#   'probabilities': array([0.86558074, 0.13441925], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.104353], dtype=float32),
#   'logits': array([-2.149767], dtype=float32),
#   'probabilities': array([0.895647, 0.104353], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6106381], dtype=float32),
#   'logits': array([0.44999528], dtype=float32),
#   'probabilities': array([0.3893619, 0.6106381], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17963134], dtype=float32),
#   'logits': array([-1.5188472], dtype=float32),
#   'probabilities': array([0.8203687 , 0.17963134], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19927037], dtype=float32),
#   'logits': array([-1.3908608], dtype=float32),
#   'probabilities': array([0.80072963, 0.19927038], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11463896], dtype=float32),
#   'logits': array([-2.0442078], dtype=float32),
#   'probabilities': array([0.885361  , 0.11463896], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16597046], dtype=float32),
#   'logits': array([-1.6144589], dtype=float32),
#   'probabilities': array([0.8340295 , 0.16597046], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23606753], dtype=float32),
#   'logits': array([-1.1743615], dtype=float32),
#   'probabilities': array([0.76393247, 0.23606753], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24883214], dtype=float32),
#   'logits': array([-1.1048506], dtype=float32),
#   'probabilities': array([0.7511679 , 0.24883214], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38036743], dtype=float32),
#   'logits': array([-0.487989], dtype=float32),
#   'probabilities': array([0.61963254, 0.38036743], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12710562], dtype=float32),
#   'logits': array([-1.9267962], dtype=float32),
#   'probabilities': array([0.8728944 , 0.12710562], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21657589], dtype=float32),
#   'logits': array([-1.2857331], dtype=float32),
#   'probabilities': array([0.78342414, 0.2165759 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20032036], dtype=float32),
#   'logits': array([-1.3842933], dtype=float32),
#   'probabilities': array([0.79967964, 0.20032036], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21355139], dtype=float32),
#   'logits': array([-1.3036499], dtype=float32),
#   'probabilities': array([0.78644866, 0.21355139], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4881553], dtype=float32),
#   'logits': array([-0.04738772], dtype=float32),
#   'probabilities': array([0.51184475, 0.4881553 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15773611], dtype=float32),
#   'logits': array([-1.67517], dtype=float32),
#   'probabilities': array([0.8422639 , 0.15773611], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22715202], dtype=float32),
#   'logits': array([-1.2244629], dtype=float32),
#   'probabilities': array([0.772848  , 0.22715203], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6464823], dtype=float32),
#   'logits': array([0.60361207], dtype=float32),
#   'probabilities': array([0.35351777, 0.6464823 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63372785], dtype=float32),
#   'logits': array([0.5482429], dtype=float32),
#   'probabilities': array([0.36627215, 0.63372785], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5143639], dtype=float32),
#   'logits': array([0.05747128], dtype=float32),
#   'probabilities': array([0.48563614, 0.5143639 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35257307], dtype=float32),
#   'logits': array([-0.6077481], dtype=float32),
#   'probabilities': array([0.64742696, 0.35257307], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48768753], dtype=float32),
#   'logits': array([-0.0492599], dtype=float32),
#   'probabilities': array([0.51231253, 0.48768756], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17231917], dtype=float32),
#   'logits': array([-1.5692792], dtype=float32),
#   'probabilities': array([0.8276808 , 0.17231917], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19204994], dtype=float32),
#   'logits': array([-1.4367449], dtype=float32),
#   'probabilities': array([0.8079501 , 0.19204992], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15166958], dtype=float32),
#   'logits': array([-1.7215658], dtype=float32),
#   'probabilities': array([0.8483304 , 0.15166958], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12320757], dtype=float32),
#   'logits': array([-1.9623997], dtype=float32),
#   'probabilities': array([0.87679243, 0.12320758], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59966385], dtype=float32),
#   'logits': array([0.40406466], dtype=float32),
#   'probabilities': array([0.40033618, 0.59966385], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22724102], dtype=float32),
#   'logits': array([-1.223956], dtype=float32),
#   'probabilities': array([0.772759  , 0.22724104], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4351318], dtype=float32),
#   'logits': array([-0.26094347], dtype=float32),
#   'probabilities': array([0.5648682 , 0.43513182], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57972455], dtype=float32),
#   'logits': array([0.32164276], dtype=float32),
#   'probabilities': array([0.42027542, 0.57972455], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.305199], dtype=float32),
#   'logits': array([-0.82266146], dtype=float32),
#   'probabilities': array([0.69480103, 0.305199  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65581065], dtype=float32),
#   'logits': array([0.6446804], dtype=float32),
#   'probabilities': array([0.3441893 , 0.65581065], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11998244], dtype=float32),
#   'logits': array([-1.9925965], dtype=float32),
#   'probabilities': array([0.8800175 , 0.11998244], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6242125], dtype=float32),
#   'logits': array([0.50746715], dtype=float32),
#   'probabilities': array([0.37578747, 0.6242125 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11866225], dtype=float32),
#   'logits': array([-2.0051599], dtype=float32),
#   'probabilities': array([0.88133776, 0.11866223], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5521078], dtype=float32),
#   'logits': array([0.20919085], dtype=float32),
#   'probabilities': array([0.44789216, 0.5521078 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3271833], dtype=float32),
#   'logits': array([-0.7209524], dtype=float32),
#   'probabilities': array([0.6728167, 0.3271833], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15853249], dtype=float32),
#   'logits': array([-1.6691879], dtype=float32),
#   'probabilities': array([0.8414675 , 0.15853247], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5536136], dtype=float32),
#   'logits': array([0.21528208], dtype=float32),
#   'probabilities': array([0.4463864, 0.5536136], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5920649], dtype=float32),
#   'logits': array([0.3725083], dtype=float32),
#   'probabilities': array([0.40793505, 0.5920649 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5557816], dtype=float32),
#   'logits': array([0.2240591], dtype=float32),
#   'probabilities': array([0.4442184, 0.5557816], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16583534], dtype=float32),
#   'logits': array([-1.6154355], dtype=float32),
#   'probabilities': array([0.8341646 , 0.16583534], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34591934], dtype=float32),
#   'logits': array([-0.63702506], dtype=float32),
#   'probabilities': array([0.6540806, 0.3459193], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14045915], dtype=float32),
#   'logits': array([-1.8114817], dtype=float32),
#   'probabilities': array([0.8595408 , 0.14045914], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7128553], dtype=float32),
#   'logits': array([0.9092921], dtype=float32),
#   'probabilities': array([0.28714472, 0.7128553 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8220622], dtype=float32),
#   'logits': array([1.5303823], dtype=float32),
#   'probabilities': array([0.17793776, 0.8220622 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6207638], dtype=float32),
#   'logits': array([0.49279118], dtype=float32),
#   'probabilities': array([0.37923628, 0.6207638 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20661014], dtype=float32),
#   'logits': array([-1.345481], dtype=float32),
#   'probabilities': array([0.79338986, 0.20661016], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44313657], dtype=float32),
#   'logits': array([-0.22844201], dtype=float32),
#   'probabilities': array([0.5568634 , 0.44313657], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3760786], dtype=float32),
#   'logits': array([-0.50622624], dtype=float32),
#   'probabilities': array([0.6239214 , 0.37607858], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46141475], dtype=float32),
#   'logits': array([-0.15464848], dtype=float32),
#   'probabilities': array([0.53858525, 0.46141475], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3469082], dtype=float32),
#   'logits': array([-0.63265747], dtype=float32),
#   'probabilities': array([0.6530918, 0.3469082], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46080858], dtype=float32),
#   'logits': array([-0.15708792], dtype=float32),
#   'probabilities': array([0.5391914 , 0.46080858], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15029055], dtype=float32),
#   'logits': array([-1.732324], dtype=float32),
#   'probabilities': array([0.84970945, 0.15029056], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.558196], dtype=float32),
#   'logits': array([0.23384392], dtype=float32),
#   'probabilities': array([0.44180393, 0.558196  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5492805], dtype=float32),
#   'logits': array([0.19776428], dtype=float32),
#   'probabilities': array([0.45071942, 0.5492805 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23637411], dtype=float32),
#   'logits': array([-1.1726623], dtype=float32),
#   'probabilities': array([0.7636259 , 0.23637411], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17262803], dtype=float32),
#   'logits': array([-1.5671152], dtype=float32),
#   'probabilities': array([0.827372  , 0.17262805], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17069782], dtype=float32),
#   'logits': array([-1.5806897], dtype=float32),
#   'probabilities': array([0.8293022 , 0.17069784], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27246928], dtype=float32),
#   'logits': array([-0.9821304], dtype=float32),
#   'probabilities': array([0.7275307 , 0.27246925], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39399242], dtype=float32),
#   'logits': array([-0.43056083], dtype=float32),
#   'probabilities': array([0.6060076, 0.3939924], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13292055], dtype=float32),
#   'logits': array([-1.8753791], dtype=float32),
#   'probabilities': array([0.8670795 , 0.13292055], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3160641], dtype=float32),
#   'logits': array([-0.77191925], dtype=float32),
#   'probabilities': array([0.68393594, 0.3160641 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21414572], dtype=float32),
#   'logits': array([-1.3001146], dtype=float32),
#   'probabilities': array([0.7858543 , 0.21414572], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08905853], dtype=float32),
#   'logits': array([-2.3251848], dtype=float32),
#   'probabilities': array([0.9109415 , 0.08905853], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11888485], dtype=float32),
#   'logits': array([-2.003033], dtype=float32),
#   'probabilities': array([0.88111514, 0.11888485], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7455325], dtype=float32),
#   'logits': array([1.0749255], dtype=float32),
#   'probabilities': array([0.25446752, 0.7455325 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1779499], dtype=float32),
#   'logits': array([-1.5302992], dtype=float32),
#   'probabilities': array([0.82205003, 0.1779499 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1266634], dtype=float32),
#   'logits': array([-1.9307878], dtype=float32),
#   'probabilities': array([0.8733366 , 0.12666342], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13419977], dtype=float32),
#   'logits': array([-1.8643247], dtype=float32),
#   'probabilities': array([0.86580026, 0.13419978], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48729864], dtype=float32),
#   'logits': array([-0.05081642], dtype=float32),
#   'probabilities': array([0.5127014 , 0.48729867], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46113226], dtype=float32),
#   'logits': array([-0.15578532], dtype=float32),
#   'probabilities': array([0.5388677, 0.4611322], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23957], dtype=float32),
#   'logits': array([-1.1550384], dtype=float32),
#   'probabilities': array([0.76043, 0.23957], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43825465], dtype=float32),
#   'logits': array([-0.2482484], dtype=float32),
#   'probabilities': array([0.56174535, 0.4382547 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17951447], dtype=float32),
#   'logits': array([-1.5196404], dtype=float32),
#   'probabilities': array([0.82048553, 0.17951448], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22015712], dtype=float32),
#   'logits': array([-1.2647511], dtype=float32),
#   'probabilities': array([0.7798429 , 0.22015712], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50202924], dtype=float32),
#   'logits': array([0.00811684], dtype=float32),
#   'probabilities': array([0.49797085, 0.50202924], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47956932], dtype=float32),
#   'logits': array([-0.08176827], dtype=float32),
#   'probabilities': array([0.5204307 , 0.47956932], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13496767], dtype=float32),
#   'logits': array([-1.8577316], dtype=float32),
#   'probabilities': array([0.8650324 , 0.13496767], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39312503], dtype=float32),
#   'logits': array([-0.4341951], dtype=float32),
#   'probabilities': array([0.60687494, 0.393125  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6869669], dtype=float32),
#   'logits': array([0.78597724], dtype=float32),
#   'probabilities': array([0.31303307, 0.6869669 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5437078], dtype=float32),
#   'logits': array([0.17527854], dtype=float32),
#   'probabilities': array([0.45629218, 0.5437078 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3936787], dtype=float32),
#   'logits': array([-0.43187487], dtype=float32),
#   'probabilities': array([0.6063213 , 0.39367872], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5556314], dtype=float32),
#   'logits': array([0.22345078], dtype=float32),
#   'probabilities': array([0.44436857, 0.5556314 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2123977], dtype=float32),
#   'logits': array([-1.3105328], dtype=float32),
#   'probabilities': array([0.7876023, 0.2123977], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18750659], dtype=float32),
#   'logits': array([-1.4662938], dtype=float32),
#   'probabilities': array([0.81249344, 0.1875066 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12957172], dtype=float32),
#   'logits': array([-1.9047508], dtype=float32),
#   'probabilities': array([0.87042826, 0.12957172], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2573411], dtype=float32),
#   'logits': array([-1.0598345], dtype=float32),
#   'probabilities': array([0.7426589, 0.2573411], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48209605], dtype=float32),
#   'logits': array([-0.07164633], dtype=float32),
#   'probabilities': array([0.5179039 , 0.48209608], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6942173], dtype=float32),
#   'logits': array([0.8199104], dtype=float32),
#   'probabilities': array([0.30578268, 0.6942173 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21981923], dtype=float32),
#   'logits': array([-1.2667202], dtype=float32),
#   'probabilities': array([0.78018075, 0.2198192 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15426481], dtype=float32),
#   'logits': array([-1.7015357], dtype=float32),
#   'probabilities': array([0.8457352, 0.1542648], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.407401], dtype=float32),
#   'logits': array([-0.37471998], dtype=float32),
#   'probabilities': array([0.592599, 0.407401], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23101918], dtype=float32),
#   'logits': array([-1.2025652], dtype=float32),
#   'probabilities': array([0.7689808, 0.2310192], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14401834], dtype=float32),
#   'logits': array([-1.7823083], dtype=float32),
#   'probabilities': array([0.85598165, 0.14401834], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1769685], dtype=float32),
#   'logits': array([-1.5370227], dtype=float32),
#   'probabilities': array([0.82303154, 0.17696851], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11848167], dtype=float32),
#   'logits': array([-2.0068877], dtype=float32),
#   'probabilities': array([0.88151836, 0.11848166], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39440435], dtype=float32),
#   'logits': array([-0.428836], dtype=float32),
#   'probabilities': array([0.60559565, 0.39440432], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7734169], dtype=float32),
#   'logits': array([1.2277066], dtype=float32),
#   'probabilities': array([0.22658308, 0.7734169 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7679592], dtype=float32),
#   'logits': array([1.1968232], dtype=float32),
#   'probabilities': array([0.23204082, 0.7679592 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5517851], dtype=float32),
#   'logits': array([0.20788586], dtype=float32),
#   'probabilities': array([0.4482149, 0.5517851], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4910765], dtype=float32),
#   'logits': array([-0.03569794], dtype=float32),
#   'probabilities': array([0.50892353, 0.49107647], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5576409], dtype=float32),
#   'logits': array([0.23159325], dtype=float32),
#   'probabilities': array([0.44235906, 0.5576409 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11269088], dtype=float32),
#   'logits': array([-2.063545], dtype=float32),
#   'probabilities': array([0.88730913, 0.11269088], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53095293], dtype=float32),
#   'logits': array([0.12397015], dtype=float32),
#   'probabilities': array([0.46904713, 0.53095293], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7679622], dtype=float32),
#   'logits': array([1.1968402], dtype=float32),
#   'probabilities': array([0.23203783, 0.7679622 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4021946], dtype=float32),
#   'logits': array([-0.39632922], dtype=float32),
#   'probabilities': array([0.5978054, 0.4021946], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25956056], dtype=float32),
#   'logits': array([-1.0482538], dtype=float32),
#   'probabilities': array([0.7404394 , 0.25956056], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3468601], dtype=float32),
#   'logits': array([-0.6328697], dtype=float32),
#   'probabilities': array([0.6531399, 0.3468601], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58043945], dtype=float32),
#   'logits': array([0.32457745], dtype=float32),
#   'probabilities': array([0.4195606 , 0.58043945], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23577006], dtype=float32),
#   'logits': array([-1.1760117], dtype=float32),
#   'probabilities': array([0.76422995, 0.23577008], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65565616], dtype=float32),
#   'logits': array([0.6439959], dtype=float32),
#   'probabilities': array([0.3443438 , 0.65565616], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40697923], dtype=float32),
#   'logits': array([-0.3764673], dtype=float32),
#   'probabilities': array([0.5930208 , 0.40697923], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40629414], dtype=float32),
#   'logits': array([-0.37930667], dtype=float32),
#   'probabilities': array([0.5937059 , 0.40629414], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15944223], dtype=float32),
#   'logits': array([-1.662384], dtype=float32),
#   'probabilities': array([0.8405578 , 0.15944223], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18703938], dtype=float32),
#   'logits': array([-1.4693636], dtype=float32),
#   'probabilities': array([0.8129606 , 0.18703936], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17556812], dtype=float32),
#   'logits': array([-1.5466675], dtype=float32),
#   'probabilities': array([0.8244319 , 0.17556812], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4404155], dtype=float32),
#   'logits': array([-0.2394759], dtype=float32),
#   'probabilities': array([0.5595845, 0.4404155], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14757188], dtype=float32),
#   'logits': array([-1.7537735], dtype=float32),
#   'probabilities': array([0.85242814, 0.14757189], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7479667], dtype=float32),
#   'logits': array([1.087797], dtype=float32),
#   'probabilities': array([0.25203335, 0.7479667 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20319197], dtype=float32),
#   'logits': array([-1.3664626], dtype=float32),
#   'probabilities': array([0.796808  , 0.20319198], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50831515], dtype=float32),
#   'logits': array([0.03326356], dtype=float32),
#   'probabilities': array([0.4916849 , 0.50831515], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15276808], dtype=float32),
#   'logits': array([-1.7130536], dtype=float32),
#   'probabilities': array([0.847232  , 0.15276808], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67434776], dtype=float32),
#   'logits': array([0.7279159], dtype=float32),
#   'probabilities': array([0.32565224, 0.67434776], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31592098], dtype=float32),
#   'logits': array([-0.77258134], dtype=float32),
#   'probabilities': array([0.68407905, 0.31592098], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18974055], dtype=float32),
#   'logits': array([-1.4516969], dtype=float32),
#   'probabilities': array([0.81025946, 0.18974055], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34051713], dtype=float32),
#   'logits': array([-0.6609906], dtype=float32),
#   'probabilities': array([0.6594829 , 0.34051713], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3265303], dtype=float32),
#   'logits': array([-0.7239202], dtype=float32),
#   'probabilities': array([0.6734697 , 0.32653034], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1600894], dtype=float32),
#   'logits': array([-1.657563], dtype=float32),
#   'probabilities': array([0.8399106 , 0.16008942], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7116853], dtype=float32),
#   'logits': array([0.90358317], dtype=float32),
#   'probabilities': array([0.2883147, 0.7116853], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18243031], dtype=float32),
#   'logits': array([-1.4999678], dtype=float32),
#   'probabilities': array([0.8175697 , 0.18243033], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16723512], dtype=float32),
#   'logits': array([-1.6053506], dtype=float32),
#   'probabilities': array([0.83276486, 0.16723512], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25939202], dtype=float32),
#   'logits': array([-1.049131], dtype=float32),
#   'probabilities': array([0.74060804, 0.25939202], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44584697], dtype=float32),
#   'logits': array([-0.21746516], dtype=float32),
#   'probabilities': array([0.554153  , 0.44584695], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26478422], dtype=float32),
#   'logits': array([-1.0212488], dtype=float32),
#   'probabilities': array([0.7352158 , 0.26478422], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11311448], dtype=float32),
#   'logits': array([-2.0593154], dtype=float32),
#   'probabilities': array([0.88688546, 0.11311448], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.84056044], dtype=float32),
#   'logits': array([1.6624035], dtype=float32),
#   'probabilities': array([0.15943964, 0.84056044], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68349326], dtype=float32),
#   'logits': array([0.7698723], dtype=float32),
#   'probabilities': array([0.3165067 , 0.68349326], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5185065], dtype=float32),
#   'logits': array([0.07405984], dtype=float32),
#   'probabilities': array([0.4814935, 0.5185065], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7227149], dtype=float32),
#   'logits': array([0.95796835], dtype=float32),
#   'probabilities': array([0.27728516, 0.7227149 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10923662], dtype=float32),
#   'logits': array([-2.0985625], dtype=float32),
#   'probabilities': array([0.89076334, 0.10923661], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14359088], dtype=float32),
#   'logits': array([-1.7857801], dtype=float32),
#   'probabilities': array([0.85640913, 0.14359088], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2024327], dtype=float32),
#   'logits': array([-1.3711587], dtype=float32),
#   'probabilities': array([0.7975673, 0.2024327], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32500276], dtype=float32),
#   'logits': array([-0.7308749], dtype=float32),
#   'probabilities': array([0.67499727, 0.3250028 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37675965], dtype=float32),
#   'logits': array([-0.50332487], dtype=float32),
#   'probabilities': array([0.62324035, 0.37675965], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57738465], dtype=float32),
#   'logits': array([0.31204617], dtype=float32),
#   'probabilities': array([0.42261538, 0.57738465], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55043733], dtype=float32),
#   'logits': array([0.20243788], dtype=float32),
#   'probabilities': array([0.44956267, 0.55043733], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37762988], dtype=float32),
#   'logits': array([-0.4996205], dtype=float32),
#   'probabilities': array([0.6223701 , 0.37762982], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36065874], dtype=float32),
#   'logits': array([-0.5725062], dtype=float32),
#   'probabilities': array([0.63934124, 0.36065874], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34677237], dtype=float32),
#   'logits': array([-0.63325703], dtype=float32),
#   'probabilities': array([0.6532276 , 0.34677237], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18305713], dtype=float32),
#   'logits': array([-1.4957709], dtype=float32),
#   'probabilities': array([0.8169429 , 0.18305713], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64281464], dtype=float32),
#   'logits': array([0.5876014], dtype=float32),
#   'probabilities': array([0.3571854 , 0.64281464], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12148878], dtype=float32),
#   'logits': array([-1.9784067], dtype=float32),
#   'probabilities': array([0.8785112 , 0.12148879], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24788134], dtype=float32),
#   'logits': array([-1.109944], dtype=float32),
#   'probabilities': array([0.75211865, 0.24788132], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55158836], dtype=float32),
#   'logits': array([0.2070905], dtype=float32),
#   'probabilities': array([0.44841158, 0.55158836], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34957087], dtype=float32),
#   'logits': array([-0.620926], dtype=float32),
#   'probabilities': array([0.6504291 , 0.34957087], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18702768], dtype=float32),
#   'logits': array([-1.4694405], dtype=float32),
#   'probabilities': array([0.81297237, 0.18702768], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2710583], dtype=float32),
#   'logits': array([-0.98925984], dtype=float32),
#   'probabilities': array([0.72894174, 0.2710583 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26256827], dtype=float32),
#   'logits': array([-1.0326624], dtype=float32),
#   'probabilities': array([0.7374317 , 0.26256827], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13094409], dtype=float32),
#   'logits': array([-1.892637], dtype=float32),
#   'probabilities': array([0.86905587, 0.13094409], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18494596], dtype=float32),
#   'logits': array([-1.4831908], dtype=float32),
#   'probabilities': array([0.81505406, 0.18494596], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5612998], dtype=float32),
#   'logits': array([0.2464391], dtype=float32),
#   'probabilities': array([0.4387001, 0.5612998], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70316243], dtype=float32),
#   'logits': array([0.86240256], dtype=float32),
#   'probabilities': array([0.29683763, 0.70316243], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61773145], dtype=float32),
#   'logits': array([0.4799304], dtype=float32),
#   'probabilities': array([0.38226855, 0.61773145], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7136298], dtype=float32),
#   'logits': array([0.9130789], dtype=float32),
#   'probabilities': array([0.28637022, 0.7136298 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44072837], dtype=float32),
#   'logits': array([-0.2382065], dtype=float32),
#   'probabilities': array([0.55927163, 0.44072837], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28989136], dtype=float32),
#   'logits': array([-0.8959117], dtype=float32),
#   'probabilities': array([0.7101086 , 0.28989136], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51148117], dtype=float32),
#   'logits': array([0.04593265], dtype=float32),
#   'probabilities': array([0.48851886, 0.51148117], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17881046], dtype=float32),
#   'logits': array([-1.5244277], dtype=float32),
#   'probabilities': array([0.8211895 , 0.17881045], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14167729], dtype=float32),
#   'logits': array([-1.8014283], dtype=float32),
#   'probabilities': array([0.85832274, 0.14167729], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17824054], dtype=float32),
#   'logits': array([-1.5283138], dtype=float32),
#   'probabilities': array([0.82175946, 0.17824054], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51041853], dtype=float32),
#   'logits': array([0.04168022], dtype=float32),
#   'probabilities': array([0.48958147, 0.51041853], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0576476], dtype=float32),
#   'logits': array([-2.7940307], dtype=float32),
#   'probabilities': array([0.9423524, 0.0576476], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27425703], dtype=float32),
#   'logits': array([-0.9731302], dtype=float32),
#   'probabilities': array([0.725743  , 0.27425703], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16131583], dtype=float32),
#   'logits': array([-1.6484702], dtype=float32),
#   'probabilities': array([0.8386842 , 0.16131581], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2599747], dtype=float32),
#   'logits': array([-1.0461001], dtype=float32),
#   'probabilities': array([0.74002534, 0.2599747 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24227746], dtype=float32),
#   'logits': array([-1.1402336], dtype=float32),
#   'probabilities': array([0.7577225 , 0.24227746], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27060357], dtype=float32),
#   'logits': array([-0.9915625], dtype=float32),
#   'probabilities': array([0.7293964 , 0.27060357], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7675821], dtype=float32),
#   'logits': array([1.1947085], dtype=float32),
#   'probabilities': array([0.2324179, 0.7675821], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17086017], dtype=float32),
#   'logits': array([-1.5795432], dtype=float32),
#   'probabilities': array([0.8291398 , 0.17086019], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12047471], dtype=float32),
#   'logits': array([-1.9879425], dtype=float32),
#   'probabilities': array([0.8795253 , 0.12047471], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58095413], dtype=float32),
#   'logits': array([0.3266914], dtype=float32),
#   'probabilities': array([0.4190459 , 0.58095413], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4677793], dtype=float32),
#   'logits': array([-0.1290617], dtype=float32),
#   'probabilities': array([0.5322207 , 0.46777928], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.85659015], dtype=float32),
#   'logits': array([1.787253], dtype=float32),
#   'probabilities': array([0.14340983, 0.85659015], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63982487], dtype=float32),
#   'logits': array([0.57460403], dtype=float32),
#   'probabilities': array([0.36017516, 0.63982487], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12141569], dtype=float32),
#   'logits': array([-1.9790918], dtype=float32),
#   'probabilities': array([0.8785843 , 0.12141569], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6402738], dtype=float32),
#   'logits': array([0.57655275], dtype=float32),
#   'probabilities': array([0.35972622, 0.6402738 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54419124], dtype=float32),
#   'logits': array([0.1772275], dtype=float32),
#   'probabilities': array([0.4558087 , 0.54419124], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7775431], dtype=float32),
#   'logits': array([1.2514056], dtype=float32),
#   'probabilities': array([0.22245692, 0.7775431 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22057886], dtype=float32),
#   'logits': array([-1.2622962], dtype=float32),
#   'probabilities': array([0.77942115, 0.22057888], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16333239], dtype=float32),
#   'logits': array([-1.6336396], dtype=float32),
#   'probabilities': array([0.83666766, 0.1633324 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5442275], dtype=float32),
#   'logits': array([0.17737341], dtype=float32),
#   'probabilities': array([0.45577255, 0.5442275 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15070729], dtype=float32),
#   'logits': array([-1.7290643], dtype=float32),
#   'probabilities': array([0.84929264, 0.15070729], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7780869], dtype=float32),
#   'logits': array([1.2545527], dtype=float32),
#   'probabilities': array([0.22191302, 0.7780869 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5248932], dtype=float32),
#   'logits': array([0.09965527], dtype=float32),
#   'probabilities': array([0.47510678, 0.5248932 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1668404], dtype=float32),
#   'logits': array([-1.6081876], dtype=float32),
#   'probabilities': array([0.83315957, 0.16684039], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5521654], dtype=float32),
#   'logits': array([0.20942366], dtype=float32),
#   'probabilities': array([0.44783458, 0.5521654 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46599755], dtype=float32),
#   'logits': array([-0.1362201], dtype=float32),
#   'probabilities': array([0.5340024 , 0.46599752], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10532475], dtype=float32),
#   'logits': array([-2.1394124], dtype=float32),
#   'probabilities': array([0.8946753 , 0.10532475], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51299036], dtype=float32),
#   'logits': array([0.05197322], dtype=float32),
#   'probabilities': array([0.48700958, 0.51299036], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5901169], dtype=float32),
#   'logits': array([0.3644489], dtype=float32),
#   'probabilities': array([0.409883 , 0.5901169], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7470989], dtype=float32),
#   'logits': array([1.0831991], dtype=float32),
#   'probabilities': array([0.25290108, 0.7470989 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8077254], dtype=float32),
#   'logits': array([1.4352976], dtype=float32),
#   'probabilities': array([0.19227462, 0.8077254 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42867854], dtype=float32),
#   'logits': array([-0.2872448], dtype=float32),
#   'probabilities': array([0.5713215, 0.4286785], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15787262], dtype=float32),
#   'logits': array([-1.6741427], dtype=float32),
#   'probabilities': array([0.8421274 , 0.15787263], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08082853], dtype=float32),
#   'logits': array([-2.4311428], dtype=float32),
#   'probabilities': array([0.91917145, 0.08082852], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10328256], dtype=float32),
#   'logits': array([-2.1612723], dtype=float32),
#   'probabilities': array([0.8967174 , 0.10328256], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2552048], dtype=float32),
#   'logits': array([-1.0710429], dtype=float32),
#   'probabilities': array([0.7447952, 0.2552048], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3172261], dtype=float32),
#   'logits': array([-0.76654893], dtype=float32),
#   'probabilities': array([0.6827739, 0.3172261], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27721447], dtype=float32),
#   'logits': array([-0.95832103], dtype=float32),
#   'probabilities': array([0.7227855 , 0.27721444], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp_325wwwb
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmp_325wwwb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a1707ce48>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# You will get an error here. This is just a demo on cat column
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-cea30273f6d4> in <module>()
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     364
#     365       saving_listeners = _check_listeners_type(saving_listeners)
# --> 366       loss = self._train_model(input_fn, hooks, saving_listeners)
#     367       logging.info('Loss for final step: %s.', loss)
#     368       return self
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1117       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1118     else:
# -> 1119       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1120
#    1121   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1130       worker_hooks.extend(input_hooks)
#    1131       estimator_spec = self._call_model_fn(
# -> 1132           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#    1133       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1134                                              hooks, global_step_tensor,
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1105
#    1106     logging.info('Calling model_fn.')
# -> 1107     model_fn_results = self._model_fn(features=features, **kwargs)
#    1108     logging.info('Done calling model_fn.')
#    1109
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     347           dropout=dropout,
#     348           input_layer_partitioner=input_layer_partitioner,
# --> 349           config=config)
#     350
#     351     super(DNNClassifier, self).__init__(
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, tpu_estimator_spec)
#     184         dropout=dropout,
#     185         input_layer_partitioner=input_layer_partitioner)
# --> 186     logits = logit_fn(features=features, mode=mode)
#     187
#     188     if tpu_estimator_spec:
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#      89         partitioner=input_layer_partitioner):
#      90       net = feature_column_lib.input_layer(
# ---> 91           features=features, feature_columns=feature_columns)
#      92     for layer_id, num_hidden_units in enumerate(hidden_units):
#      93       with variable_scope.variable_scope(
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars)
#     275   """
#     276   return _internal_input_layer(features, feature_columns, weight_collections,
# --> 277                                trainable, cols_to_vars)
#     278
#     279
#
# ~/anaconda2/envs/tfdeeplearning/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in _internal_input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars, scope)
#     179           'Items of feature_columns must be a _DenseColumn. '
#     180           'You can wrap a categorical column with an '
# --> 181           'embedding_column or indicator_column. Given: {}'.format(column))
#     182   weight_collections = list(weight_collections or [])
#     183   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmpldkfm034
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmpldkfm034', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a16d77828>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmpldkfm034/model.ckpt.
# INFO:tensorflow:loss = 7.0803595, step = 1
# INFO:tensorflow:global_step/sec: 309.711
# INFO:tensorflow:loss = 7.07422, step = 101 (0.325 sec)
# INFO:tensorflow:global_step/sec: 523.703
# INFO:tensorflow:loss = 6.728871, step = 201 (0.191 sec)
# INFO:tensorflow:global_step/sec: 501.695
# INFO:tensorflow:loss = 6.980354, step = 301 (0.198 sec)
# INFO:tensorflow:global_step/sec: 452.407
# INFO:tensorflow:loss = 5.5726643, step = 401 (0.223 sec)
# INFO:tensorflow:global_step/sec: 472.791
# INFO:tensorflow:loss = 7.5846095, step = 501 (0.209 sec)
# INFO:tensorflow:global_step/sec: 489.318
# INFO:tensorflow:loss = 6.3939924, step = 601 (0.207 sec)
# INFO:tensorflow:global_step/sec: 502.864
# INFO:tensorflow:loss = 5.0395474, step = 701 (0.196 sec)
# INFO:tensorflow:global_step/sec: 527.944
# INFO:tensorflow:loss = 3.9289517, step = 801 (0.191 sec)
# INFO:tensorflow:global_step/sec: 484.09
# INFO:tensorflow:loss = 7.1591806, step = 901 (0.209 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmpldkfm034/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.230057.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-24-01:18:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmpldkfm034/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-24-01:18:03
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7480315, accuracy_baseline = 0.65748036, auc = 0.82848096, auc_precision_recall = 0.69697267, average_loss = 0.51068145, global_step = 1000, label/mean = 0.34251967, loss = 4.988965, precision = 0.60747665, prediction/mean = 0.43857867, recall = 0.74712646
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/_6/y3kprftx5gz9pzhx9yk35dmc0000gn/T/tmpldkfm034/model.ckpt-1000
# {'accuracy': 0.7480315,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.82848096,
#  'auc_precision_recall': 0.69697267,
#  'average_loss': 0.51068145,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 4.988965,
#  'precision': 0.60747665,
#  'prediction/mean': 0.43857867,
#  'recall': 0.74712646}
