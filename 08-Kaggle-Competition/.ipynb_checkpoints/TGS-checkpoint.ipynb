# %% [markdown]
# # TGS Salt Identification Challenge
#
# ### Part of the kernel is not from mine. Used some of the expert kernel and combine all together to try.
# ### https://www.kaggle.com/c/tgs-salt-identification-challenge

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

from sklearn.model_selection import train_test_split
from tf_unet import unet, util, image_util
from tqdm import tqdm_notebook #, tnrange

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img
from tensorflow.keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

# %%
version = 1
basic_name = f'tf_unet_v{version}'
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# tf_unet_v1.model
# tf_unet_v1.csv

# %%
img_size_ori = 101
img_size_target = 101
def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("tgs/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("tgs/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)
# Out:
# 4000

# %%
train_df["images"] = [np.array(load_img("tgs/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["masks"] = [np.array(load_img("tgs/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
plt.imshow(train_df['images'][3].reshape(101,101))

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5,0,'Coverage class')

# %%
#Plotting the depth distributions¶

sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5,1,'Depth distribution')

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state= 101)

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) > 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) >= 1 and np.count_nonzero(p) == 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) == 0:
#             metric.append(1)
#             continue
        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.5)

model1 = Model(input_layer, output_layer)

c = optimizers.Adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

model1.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 101, 101, 16) 160         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 101, 101, 16) 64          conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 101, 101, 16) 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 101, 101, 16) 2320        activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 101, 101, 16) 64          conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 101, 101, 16) 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 101, 101, 16) 2320        activation_93[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 101, 101, 16) 0           conv2d_94[0][0]
#                                                                  conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 101, 101, 16) 64          add_36[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 101, 101, 16) 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 101, 101, 16) 2320        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 101, 101, 16) 64          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 101, 101, 16) 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 101, 101, 16) 2320        activation_95[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 101, 101, 16) 0           conv2d_96[0][0]
#                                                                  add_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 101, 101, 16) 64          add_37[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 101, 101, 16) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 50, 50, 16)   0           activation_96[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 50, 50, 16)   0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 50, 50, 32)   4640        dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 50, 50, 32)   128         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 50, 50, 32)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 50, 50, 32)   9248        activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 50, 50, 32)   128         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 50, 50, 32)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 50, 50, 32)   9248        activation_98[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 50, 50, 32)   0           conv2d_99[0][0]
#                                                                  conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 50, 50, 32)   128         add_38[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 50, 50, 32)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 50, 50, 32)   9248        activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 50, 50, 32)   128         conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 50, 50, 32)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 50, 50, 32)   9248        activation_100[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 50, 50, 32)   0           conv2d_101[0][0]
#                                                                  add_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 50, 50, 32)   128         add_39[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 50, 50, 32)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 25, 25, 32)   0           activation_101[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 25, 25, 32)   0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 25, 25, 64)   18496       dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 25, 25, 64)   256         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 25, 25, 64)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 25, 25, 64)   36928       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 25, 25, 64)   256         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 25, 25, 64)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 25, 25, 64)   36928       activation_103[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 25, 25, 64)   0           conv2d_104[0][0]
#                                                                  conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 25, 25, 64)   256         add_40[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 25, 25, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 25, 25, 64)   36928       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 25, 25, 64)   256         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 25, 25, 64)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 25, 25, 64)   36928       activation_105[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 25, 25, 64)   0           conv2d_106[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 25, 25, 64)   256         add_41[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 25, 25, 64)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 12, 12, 64)   0           activation_106[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 12, 12, 64)   0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 12, 12, 128)  73856       dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 12, 12, 128)  512         conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 12, 12, 128)  0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 12, 12, 128)  147584      activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 12, 12, 128)  512         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 12, 12, 128)  0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 12, 12, 128)  147584      activation_108[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 12, 12, 128)  0           conv2d_109[0][0]
#                                                                  conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 12, 12, 128)  512         add_42[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 12, 12, 128)  0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 12, 12, 128)  147584      activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 12, 12, 128)  512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 12, 12, 128)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 12, 12, 128)  147584      activation_110[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 12, 12, 128)  0           conv2d_111[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 12, 12, 128)  512         add_43[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 12, 12, 128)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 6, 6, 128)    0           activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 6, 6, 128)    0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 6, 6, 256)    295168      dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 6, 6, 256)    1024        conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 6, 6, 256)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 6, 6, 256)    590080      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 6, 6, 256)    1024        conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 6, 6, 256)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 6, 6, 256)    590080      activation_113[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 6, 6, 256)    0           conv2d_114[0][0]
#                                                                  conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 6, 6, 256)    1024        add_44[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 6, 6, 256)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 6, 6, 256)    590080      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 6, 6, 256)    1024        conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 6, 6, 256)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 6, 6, 256)    590080      activation_115[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 6, 6, 256)    0           conv2d_116[0][0]
#                                                                  add_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 6, 6, 256)    1024        add_45[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 6, 6, 256)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 12, 12, 128)  295040      activation_116[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_8[0][0]
#                                                                  activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 12, 12, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 12, 12, 128)  295040      dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 12, 12, 128)  512         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 12, 12, 128)  0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 12, 12, 128)  147584      activation_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 12, 12, 128)  512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 12, 12, 128)  0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 12, 12, 128)  147584      activation_118[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 12, 12, 128)  0           conv2d_119[0][0]
#                                                                  conv2d_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 12, 12, 128)  512         add_46[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 12, 12, 128)  0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 12, 12, 128)  147584      activation_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 12, 12, 128)  512         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 12, 12, 128)  0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 12, 12, 128)  147584      activation_120[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 12, 12, 128)  0           conv2d_121[0][0]
#                                                                  add_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 12, 12, 128)  512         add_47[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 12, 12, 128)  0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 25, 25, 64)   73792       activation_121[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 25, 25, 128)  0           conv2d_transpose_9[0][0]
#                                                                  activation_106[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 25, 25, 128)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 25, 25, 64)   73792       dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 25, 25, 64)   256         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 25, 25, 64)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 25, 25, 64)   36928       activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 25, 25, 64)   256         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 25, 25, 64)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 25, 25, 64)   36928       activation_123[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 25, 25, 64)   0           conv2d_124[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 25, 25, 64)   256         add_48[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 25, 25, 64)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 25, 25, 64)   36928       activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 25, 25, 64)   256         conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 25, 25, 64)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 25, 25, 64)   36928       activation_125[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 25, 25, 64)   0           conv2d_126[0][0]
#                                                                  add_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 25, 25, 64)   256         add_49[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 25, 25, 64)   0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 50, 50, 32)   18464       activation_126[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 50, 50, 64)   0           conv2d_transpose_10[0][0]
#                                                                  activation_101[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 50, 50, 64)   0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 50, 50, 32)   18464       dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 50, 50, 32)   128         conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 50, 50, 32)   0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 50, 50, 32)   9248        activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 50, 50, 32)   128         conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 50, 50, 32)   0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 50, 50, 32)   9248        activation_128[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 50, 50, 32)   0           conv2d_129[0][0]
#                                                                  conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 50, 50, 32)   128         add_50[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 50, 50, 32)   0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 50, 50, 32)   9248        activation_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 50, 50, 32)   128         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 50, 50, 32)   0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 50, 50, 32)   9248        activation_130[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 50, 50, 32)   0           conv2d_131[0][0]
#                                                                  add_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 50, 50, 32)   128         add_51[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 50, 50, 32)   0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 101, 101, 16) 4624        activation_131[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 101, 101, 32) 0           conv2d_transpose_11[0][0]
#                                                                  activation_96[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 101, 101, 32) 0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 101, 101, 16) 4624        dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 101, 101, 16) 64          conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 101, 101, 16) 0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 101, 101, 16) 2320        activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 101, 101, 16) 64          conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 101, 101, 16) 0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 101, 101, 16) 2320        activation_133[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 101, 101, 16) 0           conv2d_134[0][0]
#                                                                  conv2d_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 101, 101, 16) 64          add_52[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 101, 101, 16) 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 101, 101, 16) 2320        activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 101, 101, 16) 64          conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 101, 101, 16) 0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 101, 101, 16) 2320        activation_135[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 101, 101, 16) 0           conv2d_136[0][0]
#                                                                  add_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 101, 101, 16) 64          add_53[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 101, 101, 16) 0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 101, 101, 1)  17          activation_136[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 101, 101, 1)  0           conv2d_137[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint(save_model_name,monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 50
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr], 
                    verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/50
#  - 1554s - loss: 0.4270 - my_iou_metric: 0.3991 - val_loss: 9.9900 - val_my_iou_metric: 0.1505
#
# Epoch 00001: my_iou_metric improved from -inf to 0.39909, saving model to tf_unet_v1.model
# Epoch 2/50
#  - 1756s - loss: 0.3489 - my_iou_metric: 0.5064 - val_loss: 0.5952 - val_my_iou_metric: 0.2303
#
# Epoch 00002: my_iou_metric improved from 0.39909 to 0.50639, saving model to tf_unet_v1.model
# Epoch 3/50
#  - 1456s - loss: 0.3053 - my_iou_metric: 0.5480 - val_loss: 0.3501 - val_my_iou_metric: 0.4881
#
# Epoch 00003: my_iou_metric improved from 0.50639 to 0.54795, saving model to tf_unet_v1.model
# Epoch 4/50
#  - 1544s - loss: 0.2832 - my_iou_metric: 0.5568 - val_loss: 0.3732 - val_my_iou_metric: 0.5403
#
# Epoch 00004: my_iou_metric improved from 0.54795 to 0.55681, saving model to tf_unet_v1.model
# Epoch 5/50
#  - 1617s - loss: 0.2671 - my_iou_metric: 0.5722 - val_loss: 0.6562 - val_my_iou_metric: 0.4506
#
# Epoch 00005: my_iou_metric improved from 0.55681 to 0.57225, saving model to tf_unet_v1.model
# Epoch 6/50
#  - 1474s - loss: 0.2502 - my_iou_metric: 0.5846 - val_loss: 0.8598 - val_my_iou_metric: 0.3869
#
# Epoch 00006: my_iou_metric improved from 0.57225 to 0.58462, saving model to tf_unet_v1.model
# Epoch 7/50
#  - 1468s - loss: 0.2359 - my_iou_metric: 0.5931 - val_loss: 0.6129 - val_my_iou_metric: 0.2338
#
# Epoch 00007: my_iou_metric improved from 0.58462 to 0.59313, saving model to tf_unet_v1.model
# Epoch 8/50
#  - 1529s - loss: 0.2207 - my_iou_metric: 0.6138 - val_loss: 0.2437 - val_my_iou_metric: 0.6158
#
# Epoch 00008: my_iou_metric improved from 0.59313 to 0.61380, saving model to tf_unet_v1.model
# Epoch 9/50
#  - 1569s - loss: 0.2173 - my_iou_metric: 0.6210 - val_loss: 0.3459 - val_my_iou_metric: 0.5651
#
# Epoch 00009: my_iou_metric improved from 0.61380 to 0.62102, saving model to tf_unet_v1.model
# Epoch 10/50
#  - 14286s - loss: 0.2059 - my_iou_metric: 0.6352 - val_loss: 0.1866 - val_my_iou_metric: 0.6698
#
# Epoch 00010: my_iou_metric improved from 0.62102 to 0.63523, saving model to tf_unet_v1.model
# Epoch 11/50
#  - 35195s - loss: 0.2020 - my_iou_metric: 0.6436 - val_loss: 0.3090 - val_my_iou_metric: 0.6366
#
# Epoch 00011: my_iou_metric improved from 0.63523 to 0.64362, saving model to tf_unet_v1.model
# Epoch 12/50
#  - 1543s - loss: 0.1950 - my_iou_metric: 0.6525 - val_loss: 0.2936 - val_my_iou_metric: 0.5447
#
# Epoch 00012: my_iou_metric improved from 0.64362 to 0.65255, saving model to tf_unet_v1.model
# Epoch 13/50
#  - 1559s - loss: 0.1853 - my_iou_metric: 0.6664 - val_loss: 0.5249 - val_my_iou_metric: 0.4989
#
# Epoch 00013: my_iou_metric improved from 0.65255 to 0.66639, saving model to tf_unet_v1.model
# Epoch 14/50
#  - 1573s - loss: 0.1765 - my_iou_metric: 0.6800 - val_loss: 0.1716 - val_my_iou_metric: 0.7034
#
# Epoch 00014: my_iou_metric improved from 0.66639 to 0.67998, saving model to tf_unet_v1.model
# Epoch 15/50
#  - 1543s - loss: 0.1661 - my_iou_metric: 0.6827 - val_loss: 0.4238 - val_my_iou_metric: 0.5463
#
# Epoch 00015: my_iou_metric improved from 0.67998 to 0.68269, saving model to tf_unet_v1.model
# Epoch 16/50
#  - 1476s - loss: 0.1639 - my_iou_metric: 0.6921 - val_loss: 0.1536 - val_my_iou_metric: 0.7259
#
# Epoch 00016: my_iou_metric improved from 0.68269 to 0.69209, saving model to tf_unet_v1.model
# Epoch 17/50
#  - 1436s - loss: 0.1620 - my_iou_metric: 0.6930 - val_loss: 0.1616 - val_my_iou_metric: 0.7150
#
# Epoch 00017: my_iou_metric improved from 0.69209 to 0.69298, saving model to tf_unet_v1.model
# Epoch 18/50
#  - 1518s - loss: 0.1556 - my_iou_metric: 0.7022 - val_loss: 0.2483 - val_my_iou_metric: 0.6216
#
# Epoch 00018: my_iou_metric improved from 0.69298 to 0.70217, saving model to tf_unet_v1.model
# Epoch 19/50
#  - 1545s - loss: 0.1576 - my_iou_metric: 0.7010 - val_loss: 0.2076 - val_my_iou_metric: 0.7273
#
# Epoch 00019: my_iou_metric did not improve from 0.70217
# Epoch 20/50
#  - 1752s - loss: 0.1543 - my_iou_metric: 0.7101 - val_loss: 0.1910 - val_my_iou_metric: 0.6813
#
# Epoch 00020: my_iou_metric improved from 0.70217 to 0.71012, saving model to tf_unet_v1.model
# Epoch 21/50
#  - 1437s - loss: 0.1554 - my_iou_metric: 0.7053 - val_loss: 0.1941 - val_my_iou_metric: 0.7039
#
# Epoch 00021: my_iou_metric did not improve from 0.71012
# Epoch 22/50
#  - 1428s - loss: 0.1514 - my_iou_metric: 0.7110 - val_loss: 0.3390 - val_my_iou_metric: 0.6072
#
# Epoch 00022: my_iou_metric improved from 0.71012 to 0.71095, saving model to tf_unet_v1.model
# Epoch 23/50
#  - 1426s - loss: 0.1478 - my_iou_metric: 0.7155 - val_loss: 0.2124 - val_my_iou_metric: 0.6707
#
# Epoch 00023: my_iou_metric improved from 0.71095 to 0.71553, saving model to tf_unet_v1.model
# Epoch 24/50
#  - 1423s - loss: 0.1422 - my_iou_metric: 0.7183 - val_loss: 0.2084 - val_my_iou_metric: 0.6986
#
# Epoch 00024: my_iou_metric improved from 0.71553 to 0.71831, saving model to tf_unet_v1.model
# Epoch 25/50
#  - 1489s - loss: 0.1419 - my_iou_metric: 0.7238 - val_loss: 0.2064 - val_my_iou_metric: 0.6635
#
# Epoch 00025: my_iou_metric improved from 0.71831 to 0.72384, saving model to tf_unet_v1.model
# Epoch 26/50
#  - 1531s - loss: 0.1450 - my_iou_metric: 0.7145 - val_loss: 0.1894 - val_my_iou_metric: 0.6804
#
# Epoch 00026: my_iou_metric did not improve from 0.72384
# Epoch 27/50
#  - 1471s - loss: 0.1378 - my_iou_metric: 0.7291 - val_loss: 0.2286 - val_my_iou_metric: 0.6650
#
# Epoch 00027: my_iou_metric improved from 0.72384 to 0.72906, saving model to tf_unet_v1.model
# Epoch 28/50
#  - 1444s - loss: 0.1306 - my_iou_metric: 0.7337 - val_loss: 0.1596 - val_my_iou_metric: 0.7230
#
# Epoch 00028: my_iou_metric improved from 0.72906 to 0.73372, saving model to tf_unet_v1.model
# Epoch 29/50
#  - 1378s - loss: 0.1303 - my_iou_metric: 0.7307 - val_loss: 0.1756 - val_my_iou_metric: 0.7291
#
# Epoch 00029: my_iou_metric did not improve from 0.73372
# Epoch 30/50
#  - 1386s - loss: 0.1271 - my_iou_metric: 0.7395 - val_loss: 0.2730 - val_my_iou_metric: 0.6364
#
# Epoch 00030: my_iou_metric improved from 0.73372 to 0.73945, saving model to tf_unet_v1.model
# Epoch 31/50
#  - 1391s - loss: 0.1264 - my_iou_metric: 0.7428 - val_loss: 0.2611 - val_my_iou_metric: 0.6051
#
# Epoch 00031: my_iou_metric improved from 0.73945 to 0.74284, saving model to tf_unet_v1.model
# Epoch 32/50
#  - 1390s - loss: 0.1274 - my_iou_metric: 0.7329 - val_loss: 0.1567 - val_my_iou_metric: 0.7164
#
# Epoch 00032: my_iou_metric did not improve from 0.74284
# Epoch 33/50
#  - 1377s - loss: 0.1274 - my_iou_metric: 0.7390 - val_loss: 0.3556 - val_my_iou_metric: 0.5376
#
# Epoch 00033: my_iou_metric did not improve from 0.74284
# Epoch 34/50
#  - 1375s - loss: 0.1346 - my_iou_metric: 0.7261 - val_loss: 0.1819 - val_my_iou_metric: 0.7238
#
# Epoch 00034: my_iou_metric did not improve from 0.74284
# Epoch 35/50
#  - 1455s - loss: 0.1194 - my_iou_metric: 0.7445 - val_loss: 0.1548 - val_my_iou_metric: 0.7265
#
# Epoch 00035: my_iou_metric improved from 0.74284 to 0.74450, saving model to tf_unet_v1.model
# Epoch 36/50
#  - 1505s - loss: 0.1188 - my_iou_metric: 0.7452 - val_loss: 0.1492 - val_my_iou_metric: 0.7374
#
# Epoch 00036: my_iou_metric improved from 0.74450 to 0.74516, saving model to tf_unet_v1.model
# Epoch 37/50
#  - 1538s - loss: 0.1162 - my_iou_metric: 0.7474 - val_loss: 0.1499 - val_my_iou_metric: 0.7416
#
# Epoch 00037: my_iou_metric improved from 0.74516 to 0.74744, saving model to tf_unet_v1.model
# Epoch 38/50
#  - 1522s - loss: 0.1192 - my_iou_metric: 0.7493 - val_loss: 0.1301 - val_my_iou_metric: 0.7546
#
# Epoch 00038: my_iou_metric improved from 0.74744 to 0.74927, saving model to tf_unet_v1.model
# Epoch 39/50
#  - 1514s - loss: 0.1107 - my_iou_metric: 0.7558 - val_loss: 0.1473 - val_my_iou_metric: 0.7411
#
# Epoch 00039: my_iou_metric improved from 0.74927 to 0.75575, saving model to tf_unet_v1.model
# Epoch 40/50
#  - 1519s - loss: 0.1106 - my_iou_metric: 0.7548 - val_loss: 0.3328 - val_my_iou_metric: 0.6525
#
# Epoch 00040: my_iou_metric did not improve from 0.75575
# Epoch 41/50
#  - 1522s - loss: 0.1096 - my_iou_metric: 0.7565 - val_loss: 0.3900 - val_my_iou_metric: 0.5039
#
# Epoch 00041: my_iou_metric improved from 0.75575 to 0.75653, saving model to tf_unet_v1.model
# Epoch 42/50
#  - 1527s - loss: 0.1068 - my_iou_metric: 0.7585 - val_loss: 0.1368 - val_my_iou_metric: 0.7493
#
# Epoch 00042: my_iou_metric improved from 0.75653 to 0.75847, saving model to tf_unet_v1.model
# Epoch 43/50
#  - 1534s - loss: 0.1078 - my_iou_metric: 0.7592 - val_loss: 0.3142 - val_my_iou_metric: 0.6714
#
# Epoch 00043: my_iou_metric improved from 0.75847 to 0.75922, saving model to tf_unet_v1.model
# Epoch 44/50
#  - 1538s - loss: 0.1070 - my_iou_metric: 0.7599 - val_loss: 0.2260 - val_my_iou_metric: 0.6965
#
# Epoch 00044: my_iou_metric improved from 0.75922 to 0.75994, saving model to tf_unet_v1.model
# Epoch 45/50
#  - 1542s - loss: 0.1018 - my_iou_metric: 0.7582 - val_loss: 0.2012 - val_my_iou_metric: 0.7039
#
# Epoch 00045: my_iou_metric did not improve from 0.75994
# Epoch 46/50
#  - 1547s - loss: 0.1095 - my_iou_metric: 0.7524 - val_loss: 0.1473 - val_my_iou_metric: 0.7375
#
# Epoch 00046: my_iou_metric did not improve from 0.75994
# Epoch 47/50
#  - 1550s - loss: 0.1019 - my_iou_metric: 0.7666 - val_loss: 0.1672 - val_my_iou_metric: 0.7325
#
# Epoch 00047: my_iou_metric improved from 0.75994 to 0.76663, saving model to tf_unet_v1.model
# Epoch 48/50
#  - 1551s - loss: 0.1000 - my_iou_metric: 0.7666 - val_loss: 0.1527 - val_my_iou_metric: 0.7469
#
# Epoch 00048: my_iou_metric did not improve from 0.76663
# Epoch 49/50
#  - 1552s - loss: 0.0970 - my_iou_metric: 0.7653 - val_loss: 0.1839 - val_my_iou_metric: 0.7464
#
# Epoch 00049: my_iou_metric did not improve from 0.76663
# Epoch 50/50
#  - 1552s - loss: 0.1001 - my_iou_metric: 0.7657 - val_loss: 0.1670 - val_my_iou_metric: 0.7459
#
# Epoch 00050: my_iou_metric did not improve from 0.76663

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.Adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
epochs = 50
batch_size = 32

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr,early_stopping], 
                    verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/50
#  - 1611s - loss: 0.4293 - my_iou_metric_2: 0.7724 - val_loss: 0.4427 - val_my_iou_metric_2: 0.7593
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.75925, saving model to tf_unet_v1.model
# Epoch 2/50
#  - 1572s - loss: 0.3886 - my_iou_metric_2: 0.7820 - val_loss: 0.4666 - val_my_iou_metric_2: 0.7421
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.75925
# Epoch 3/50
#  - 1512s - loss: 0.3898 - my_iou_metric_2: 0.7775 - val_loss: 0.4862 - val_my_iou_metric_2: 0.7265
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.75925
# Epoch 4/50
#  - 1537s - loss: 0.3822 - my_iou_metric_2: 0.7818 - val_loss: 0.4515 - val_my_iou_metric_2: 0.7515
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.75925
# Epoch 5/50
#  - 1432s - loss: 0.3731 - my_iou_metric_2: 0.7866 - val_loss: 0.5470 - val_my_iou_metric_2: 0.7022
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.75925
# Epoch 6/50
#  - 1420s - loss: 0.3854 - my_iou_metric_2: 0.7790 - val_loss: 0.5420 - val_my_iou_metric_2: 0.7141
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.75925
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 7/50
#  - 1469s - loss: 0.3478 - my_iou_metric_2: 0.7976 - val_loss: 0.4346 - val_my_iou_metric_2: 0.7570
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.75925
# Epoch 8/50
#  - 1502s - loss: 0.3355 - my_iou_metric_2: 0.8026 - val_loss: 0.4004 - val_my_iou_metric_2: 0.7727
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.75925 to 0.77275, saving model to tf_unet_v1.model
# Epoch 9/50
#  - 1544s - loss: 0.3303 - my_iou_metric_2: 0.8058 - val_loss: 0.4048 - val_my_iou_metric_2: 0.7710
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.77275
# Epoch 10/50
#  - 1461s - loss: 0.3344 - my_iou_metric_2: 0.8039 - val_loss: 0.4417 - val_my_iou_metric_2: 0.7504
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.77275
# Epoch 11/50
#  - 1398s - loss: 0.3211 - my_iou_metric_2: 0.8097 - val_loss: 0.3993 - val_my_iou_metric_2: 0.7730
#
# Epoch 00011: val_my_iou_metric_2 improved from 0.77275 to 0.77300, saving model to tf_unet_v1.model
# Epoch 12/50
#  - 1397s - loss: 0.3279 - my_iou_metric_2: 0.8048 - val_loss: 0.3826 - val_my_iou_metric_2: 0.7791
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.77300 to 0.77912, saving model to tf_unet_v1.model
# Epoch 13/50
#  - 1387s - loss: 0.3212 - my_iou_metric_2: 0.8086 - val_loss: 0.4082 - val_my_iou_metric_2: 0.7750
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.77912
# Epoch 14/50
#  - 1382s - loss: 0.3191 - my_iou_metric_2: 0.8101 - val_loss: 0.3903 - val_my_iou_metric_2: 0.7722
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.77912
# Epoch 15/50
#  - 1403s - loss: 0.3198 - my_iou_metric_2: 0.8096 - val_loss: 0.4258 - val_my_iou_metric_2: 0.7561
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.77912
# Epoch 16/50
#  - 1528s - loss: 0.3219 - my_iou_metric_2: 0.8094 - val_loss: 0.3895 - val_my_iou_metric_2: 0.7756
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.77912
# Epoch 17/50
#  - 1548s - loss: 0.3193 - my_iou_metric_2: 0.8093 - val_loss: 0.3778 - val_my_iou_metric_2: 0.7816
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.77912 to 0.78163, saving model to tf_unet_v1.model
# Epoch 18/50
#  - 1402s - loss: 0.3264 - my_iou_metric_2: 0.8069 - val_loss: 0.4014 - val_my_iou_metric_2: 0.7718
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.78163
# Epoch 19/50
#  - 1386s - loss: 0.3217 - my_iou_metric_2: 0.8085 - val_loss: 0.3864 - val_my_iou_metric_2: 0.7759
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.78163
# Epoch 20/50
#  - 1398s - loss: 0.3181 - my_iou_metric_2: 0.8087 - val_loss: 0.3749 - val_my_iou_metric_2: 0.7834
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.78163 to 0.78338, saving model to tf_unet_v1.model
# Epoch 21/50
#  - 1571s - loss: 0.3194 - my_iou_metric_2: 0.8090 - val_loss: 0.3634 - val_my_iou_metric_2: 0.7885
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.78338 to 0.78850, saving model to tf_unet_v1.model
# Epoch 22/50
#  - 1614s - loss: 0.3084 - my_iou_metric_2: 0.8164 - val_loss: 0.3881 - val_my_iou_metric_2: 0.7744
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.78850
# Epoch 23/50
#  - 1360s - loss: 0.3169 - my_iou_metric_2: 0.8109 - val_loss: 0.3728 - val_my_iou_metric_2: 0.7849
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.78850
# Epoch 24/50
#  - 1227s - loss: 0.3185 - my_iou_metric_2: 0.8100 - val_loss: 0.3873 - val_my_iou_metric_2: 0.7773
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.78850
# Epoch 25/50
#  - 1227s - loss: 0.3139 - my_iou_metric_2: 0.8131 - val_loss: 0.3666 - val_my_iou_metric_2: 0.7905
#
# Epoch 00025: val_my_iou_metric_2 improved from 0.78850 to 0.79050, saving model to tf_unet_v1.model
# Epoch 26/50
#  - 1242s - loss: 0.3221 - my_iou_metric_2: 0.8087 - val_loss: 0.3802 - val_my_iou_metric_2: 0.7792
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.79050
# Epoch 27/50
#  - 1258s - loss: 0.3142 - my_iou_metric_2: 0.8126 - val_loss: 0.3776 - val_my_iou_metric_2: 0.7829
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.79050
# Epoch 28/50
#  - 1278s - loss: 0.3157 - my_iou_metric_2: 0.8099 - val_loss: 0.3593 - val_my_iou_metric_2: 0.7885
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.79050
# Epoch 29/50
#  - 1279s - loss: 0.3150 - my_iou_metric_2: 0.8098 - val_loss: 0.3641 - val_my_iou_metric_2: 0.7846
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.79050
# Epoch 30/50
#  - 1282s - loss: 0.3091 - my_iou_metric_2: 0.8156 - val_loss: 0.4083 - val_my_iou_metric_2: 0.7669
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.79050
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 31/50
#  - 1286s - loss: 0.2858 - my_iou_metric_2: 0.8268 - val_loss: 0.3562 - val_my_iou_metric_2: 0.7915
#
# Epoch 00031: val_my_iou_metric_2 improved from 0.79050 to 0.79150, saving model to tf_unet_v1.model
# Epoch 32/50
#  - 1291s - loss: 0.2909 - my_iou_metric_2: 0.8228 - val_loss: 0.3565 - val_my_iou_metric_2: 0.7903
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.79150
# Epoch 33/50
#  - 1292s - loss: 0.2835 - my_iou_metric_2: 0.8262 - val_loss: 0.3456 - val_my_iou_metric_2: 0.7937
#
# Epoch 00033: val_my_iou_metric_2 improved from 0.79150 to 0.79375, saving model to tf_unet_v1.model
# Epoch 34/50
#  - 1296s - loss: 0.2840 - my_iou_metric_2: 0.8250 - val_loss: 0.4103 - val_my_iou_metric_2: 0.7584
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.79375
# Epoch 35/50
#  - 1297s - loss: 0.2942 - my_iou_metric_2: 0.8219 - val_loss: 0.3676 - val_my_iou_metric_2: 0.7856
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.79375
# Epoch 36/50
#  - 1302s - loss: 0.2849 - my_iou_metric_2: 0.8260 - val_loss: 0.3633 - val_my_iou_metric_2: 0.7874
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.79375
# Epoch 37/50
#  - 1300s - loss: 0.2866 - my_iou_metric_2: 0.8261 - val_loss: 0.3530 - val_my_iou_metric_2: 0.7905
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.79375
# Epoch 38/50
#  - 1303s - loss: 0.2784 - my_iou_metric_2: 0.8297 - val_loss: 0.3615 - val_my_iou_metric_2: 0.7835
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.79375
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 39/50
#  - 1304s - loss: 0.2736 - my_iou_metric_2: 0.8318 - val_loss: 0.3874 - val_my_iou_metric_2: 0.7781
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.79375
# Epoch 40/50
#  - 1304s - loss: 0.2718 - my_iou_metric_2: 0.8334 - val_loss: 0.3564 - val_my_iou_metric_2: 0.7910
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.79375
# Epoch 41/50
#  - 1307s - loss: 0.2691 - my_iou_metric_2: 0.8344 - val_loss: 0.3392 - val_my_iou_metric_2: 0.7964
#
# Epoch 00041: val_my_iou_metric_2 improved from 0.79375 to 0.79638, saving model to tf_unet_v1.model
# Epoch 42/50
#  - 1309s - loss: 0.2644 - my_iou_metric_2: 0.8376 - val_loss: 0.3547 - val_my_iou_metric_2: 0.7918
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.79638
# Epoch 43/50
#  - 1309s - loss: 0.2641 - my_iou_metric_2: 0.8377 - val_loss: 0.3432 - val_my_iou_metric_2: 0.7954
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.79638
# Epoch 44/50
#  - 1309s - loss: 0.2630 - my_iou_metric_2: 0.8366 - val_loss: 0.3377 - val_my_iou_metric_2: 0.7987
# Epoch 00044: val_my_iou_metric_2 improved from 0.79638 to 0.79875, saving model to tf_unet_v1.model
# Epoch 45/50
#  - 1311s - loss: 0.2676 - my_iou_metric_2: 0.8357 - val_loss: 0.3424 - val_my_iou_metric_2: 0.7960
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.79875
# Epoch 46/50
#  - 1311s - loss: 0.2647 - my_iou_metric_2: 0.8358 - val_loss: 0.3436 - val_my_iou_metric_2: 0.7945
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.79875
# Epoch 47/50
#  - 1312s - loss: 0.2715 - my_iou_metric_2: 0.8338 - val_loss: 0.3437 - val_my_iou_metric_2: 0.7970
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.79875
# Epoch 48/50
#  - 1312s - loss: 0.2649 - my_iou_metric_2: 0.8366 - val_loss: 0.3532 - val_my_iou_metric_2: 0.7908
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.79875
# Epoch 49/50
#  - 1312s - loss: 0.2685 - my_iou_metric_2: 0.8341 - val_loss: 0.3533 - val_my_iou_metric_2: 0.7936
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.79875
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 50/50
#  - 1313s - loss: 0.2657 - my_iou_metric_2: 0.8358 - val_loss: 0.3479 - val_my_iou_metric_2: 0.7951
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.79875

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
preds_valid = predict_result(model,x_valid,img_size_target)

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))
#     temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))
    #print(temp1)
    intersection = temp1[0]
    #print("temp2 = ",temp1[1])
    #print(intersection.shape)
   # print(intersection)
    # Compute areas (needed for finding the union between all objects)
    #print(np.histogram(labels, bins = true_objects))
    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    #print("area_true = ",area_true)
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
  
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.799    0.79975  0.800875 0.80075  0.80075  0.800375 0.800375 0.80075
#  0.800375 0.799875 0.7995   0.79925  0.798875 0.798375 0.801    0.79775
#  0.798875 0.7985   0.798375 0.797875 0.7985   0.7995   0.7985   0.7975
#  0.79725  0.79675  0.796    0.795625 0.79475  0.794125 0.79575 ]

# %%
# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
"""
used for converting the decoded image to rle mask
Fast compared to previous one
"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array([(np.array(load_img("tgs/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
preds_test = predict_result(model,x_test,img_size_target)

# %%
import time
t_start = time.time()

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Usedtime = 4.398468732833862 s

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submission_file)

# %%
t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# Kernel run time = 0.029950591921806335 hours
